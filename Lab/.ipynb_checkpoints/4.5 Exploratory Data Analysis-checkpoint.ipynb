# %% [markdown]
# # Lab Instructions
#
# Choose your own adventure! In this lab, you will select a dataset, identify the target feature, and determine what relationships are present between the target and the other features in the data.
#
# The dataset should have at least 5 features plus the target and at least a few hundred rows.  If the original dataset has more than 5 features, you may select the 5 that seem most interesting for this project. The subject can be anything you choose.
#
# For your lab submission, describe the dataset and the features - including all of the values of the features - and identify the target feature.  Then make visualizations to show the relationship of each feature to the target.  Which feature(s) seem most related?  Which features don't seem to influence the value of the target?  Draw at least one big picture conclusion about your data from the visualizations you've created.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Lab 4.5 — Exploratory Data Analysis (EDA) on Remote Work Productivity
# **Student:** Nicholas Keilholz
# **Dataset:** Remote Work Productivity (Kaggle, by MrSimple)
# **Goal:**
# Analyze how employment type (Remote vs In-Office), working hours, and well-being affect employee productivity.
# This analysis uses descriptive statistics and visualizations to uncover relationships between features and the target variable `Productivity_Score`.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------

# %%
import pandas as pd

# Load dataset
file_path = "remote_work_productivity.csv"
df = pd.read_csv(file_path)

# Preview
df.head()
# Out:
#    Employee_ID Employment_Type  Hours_Worked_Per_Week  Productivity_Score  \
# 0            1          Remote                     29                  75
# 1            2       In-Office                     45                  49
# 2            3          Remote                     34                  74
# 3            4          Remote                     25                  81
# 4            5          Remote                     50                  70
#
#    Well_Being_Score
# 0                78
# 1                47
# 2                89
# 3                84
# 4                74

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set(style="whitegrid")

# Histograms
df[['Hours_Worked_Per_Week', 'Productivity_Score', 'Well_Being_Score']].hist(
    bins=10, figsize=(12, 6), edgecolor='black'
)
plt.suptitle("Distribution of Key Variables", fontsize=14)
plt.show()

# %% [markdown]
# ### Interpretation:
#
# The histograms show that most employees work between 25–45 hours per week. Both Productivity Score and Well-Being Score are roughly bell-shaped, suggesting a normal distribution centered near 70–80. This indicates most employees are moderately productive and generally satisfied, with only a few extreme outliers on either end.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------

# %%
plt.figure(figsize=(6,5))
sns.boxplot(x='Employment_Type', y='Productivity_Score', data=df, palette='Set2')
plt.title("Productivity Score by Employment Type")
plt.ylabel("Productivity Score")
plt.xlabel("Employment Type")
plt.show()
# Out:
# C:\Users\15733\AppData\Local\Temp\ipykernel_4952\902569835.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Employment_Type', y='Productivity_Score', data=df, palette='Set2')

# %% [markdown]
# ### Interpretation:
#
# The dataset shows two main employment groups: Remote and In-Office.
# Histograms suggest most employees work between 25–45 hours per week, with productivity and well-being generally skewed toward higher values.
# The boxplot shows that remote employees tend to have slightly higher median productivity than in-office employees.
# The heatmap indicates a moderate positive correlation between Well_Being_Score and Productivity_Score, suggesting that better well-being is associated with higher productivity.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# ===== Scatterplot 1: Hours Worked vs Productivity =====
plt.figure(figsize=(6,5))
sns.regplot(
    x='Hours_Worked_Per_Week',
    y='Productivity_Score',
    data=df,
    scatter_kws={'alpha':0.6},
    line_kws={'color':'blue'}
)
plt.title("Hours Worked vs Productivity Score")
plt.xlabel("Hours Worked Per Week")
plt.ylabel("Productivity Score")
plt.show()  # <-- closes first plot cleanly

# ===== Scatterplot 2: Well-Being vs Productivity =====
plt.figure(figsize=(6,5))
sns.regplot(
    x='Well_Being_Score',
    y='Productivity_Score',
    data=df,
    scatter_kws={'alpha':0.6},
    line_kws={'color':'red'}
)
plt.title("Well-Being vs Productivity Score")
plt.xlabel("Well-Being Score")
plt.ylabel("Productivity Score")
plt.show()  # <-- closes second plot cleanly

# %% [markdown]
# ### Interpretation:
#
# *Scatterplot 1*
#
# The downward trendline suggests a negative relationship, as employees work more hours per week, their productivity tends to decrease slightly. This may indicate fatigue or diminishing returns from overwork, emphasizing that longer hours don’t necessarily lead to better performance.
#
# *Scatterplot 2*
#
# The upward trendline indicates a positive correlation, higher well-being is associated with higher productivity. Employees who report feeling better mentally and emotionally tend to perform at a stronger, more consistent level.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------

# %%
plt.figure(figsize=(6,4))
sns.barplot(x='Employment_Type', y='Productivity_Score', data=df, ci=None, palette='coolwarm')
plt.title("Average Productivity by Employment Type")
plt.ylabel("Average Productivity Score")
plt.xlabel("Employment Type")
plt.show()
# Out:
# C:\Users\15733\AppData\Local\Temp\ipykernel_4952\3362002934.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Employment_Type', y='Productivity_Score', data=df, ci=None, palette='coolwarm')
# C:\Users\15733\AppData\Local\Temp\ipykernel_4952\3362002934.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Employment_Type', y='Productivity_Score', data=df, ci=None, palette='coolwarm')

# %% [markdown]
# ### Interpretation:
#
# The bar chart reinforces the earlier boxplot result: remote workers show a slightly higher average productivity score compared to in-office workers. This supports the idea that flexible work environments may enhance both motivation and efficiency.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Dataset and Feature Relationships
#
# **Dataset Overview:**
# The *Remote Work Productivity* dataset includes 1,000 employee records and the following features:
# - **Employee_ID:** Unique identifier for each employee
# - **Employment_Type:** Remote or In-Office
# - **Hours_Worked_Per_Week:** Number of hours worked each week
# - **Productivity_Score:** Overall performance score (**Target Feature**)
# - **Well_Being_Score:** Self-reported physical and mental well-being level
#
# There are no missing values, and all columns are properly formatted for analysis.
#
# ---
#
# **Most Related Features:**
# - **Well_Being_Score** – Shows the strongest positive correlation with productivity; employees with higher well-being tend to be more productive.
# - **Employment_Type** – Remote employees generally score slightly higher on productivity than in-office employees.
#
# **Less Related Features:**
# - **Hours_Worked_Per_Week** – Displays a weak negative relationship; working more hours doesn’t always increase productivity.
# - **Employee_ID** – Has no analytical value; used only for identification.
#
# ---
#
# **Summary Insight:**
# Well-being has the greatest influence on productivity, followed by employment type. Hours worked per week shows diminishing returns, indicating that overwork can slightly lower productivity.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Summary & Conclusion:
#
# This analysis suggests that remote employees generally achieve higher productivity and well-being compared to in-office counterparts. While working more hours shows a mild negative effect on productivity, higher well-being scores are strongly linked to better performance.
#
# The findings highlight that work quality and balance matter more than quantity of hours. Promoting flexible schedules and wellness support may improve overall output and job satisfaction in remote or hybrid work environments.
